# %%
import pandas as pd
import numpy as np

print("NBA analytics environment is working!")
# Out:
# NBA analytics environment is working!

# %%
print(pd.__version__)
print(np.__version__)
# Out:
# 3.0.5
# 2.5.2
